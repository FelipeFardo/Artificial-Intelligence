# %%
# pipenv install pandas seaborn pyplot scikit-learn matplotlib ipywidgets ipykernel plotly

# EDA e Visualização de Dados
import pandas as pd
import plotly.express as px
import seaborn as sns

# ML / tSNE
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.manifold import TSNE

# %% [markdown]
# ### Carregar os dados

# %%
# Carregar DataFrame
df_cosmetics = pd.read_csv('./datasets/cosmetics.csv')

# %%
df_cosmetics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           1472 non-null   object
#  1   Marca          1472 non-null   object
#  2   Nome           1472 non-null   object
#  3   Preco          1472 non-null   int64
#  4   Rating         1472 non-null   float64
#  5   Ingredientes   1472 non-null   object
#  6   Pele_Mista     1472 non-null   int64
#  7   Pele_Seca      1472 non-null   int64
#  8   Pele_Normal    1472 non-null   int64
#  9   Pele_Oleosa    1472 non-null   int64
#  10  Pele_Sensivel  1472 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 126.6+ KB

# %%
# Visualizar os primeiros registro
df_cosmetics.head(10)
# Out:
#           Tipo               Marca  \
# 0  Moisturizer              LA MER
# 1  Moisturizer               SK-II
# 2  Moisturizer      DRUNK ELEPHANT
# 3  Moisturizer              LA MER
# 4  Moisturizer        IT COSMETICS
# 5  Moisturizer              TATCHA
# 6  Moisturizer      DRUNK ELEPHANT
# 7  Moisturizer      DRUNK ELEPHANT
# 8  Moisturizer  KIEHL'S SINCE 1851
# 9  Moisturizer              LA MER
#
#                                                 Nome  Preco  Rating  \
# 0                                    Crème de la Mer    175     4.1
# 1                           Facial Treatment Essence    179     4.1
# 2                         Protini™ Polypeptide Cream     68     4.4
# 3                        The Moisturizing Soft Cream    175     3.8
# 4      Your Skin But Better™ CC+™ Cream with SPF 50+     38     4.1
# 5                                    The Water Cream     68     4.2
# 6                          Lala Retro™ Whipped Cream     60     4.2
# ...

# %%
# Visualizar os últimos registro
df_cosmetics.tail(10)
# Out:
#              Tipo                          Marca  \
# 1462  Sun protect                          COOLA
# 1463  Sun protect                  VITA LIBERATA
# 1464  Sun protect                   IT COSMETICS
# 1465  Sun protect                    URBAN DECAY
# 1466  Sun protect                KATE SOMERVILLE
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Nome  Preco  Rating  \
# 1462                                         Summer Duo     36     4.8
# 1463  Passionflower & Argan Dry Oil Broad Spectrum S...     45     4.2
# 1464  Anti-Aging Armour™ Super Smart Skin-Perfecting...     38     4.1
# 1465  Naked Skin Bronzing Beauty Balm Broad Spectrum...     34     4.1
# ...

# %% [markdown]
# ### EDA

# %% [markdown]
# Transformar valores da coluna "Ingredientes" em um novo Dataframe

# %%
df_cosmetics_eda = df_cosmetics.copy()
df_cosmetics_eda = df_cosmetics_eda['Ingredientes'].str.split(',')

# %%
df_cosmetics_eda
# Out:
# 0       [Algae (Seaweed) Extract,  Mineral Oil,  Petro...
# 1       [Galactomyces Ferment Filtrate (Pitera),  Buty...
# 2       [Water,  Dicaprylyl Carbonate,  Glycerin,  Cet...
# 3       [Algae (Seaweed) Extract,  Cyclopentasiloxane,...
# 4       [Water,  Snail Secretion Filtrate,  Phenyl Tri...
#                               ...
# 1467    [Water,  Alcohol Denat.,  Potassium Cetyl Phos...
# 1468    [Water,  Isododecane,  Dimethicone,  Butylocty...
# 1469    [Water,  Dihydroxyacetone,  Glycerin,  Scleroc...
# 1470    [Water,  Dihydroxyacetone,  Propylene Glycol, ...
# 1471                      [Visit the DERMAFLASH boutique]
# Name: Ingredientes, Length: 1472, dtype: object

# %%
df_ingredients = df_cosmetics_eda.explode('Ingredientes')

# %%
df_ingredients
# Out:
# 0              Algae (Seaweed) Extract
# 1                          Mineral Oil
# 2                           Petrolatum
# 3                             Glycerin
# 4                        Isohexadecane
#                      ...
# 45811           Alpha-isomethyl Ionone
# 45812                 CI 14700 (Red 4)
# 45813              CI 19140 (Yellow 5)
# 45814               CI 42090 (Blue 1).
# 45815    Visit the DERMAFLASH boutique
# Name: Ingredientes, Length: 45816, dtype: object

# %% [markdown]
# Análise univariada

# %%
# Estatisticas das Variáveis
df_cosmetics.describe()
# Out:
#              Preco       Rating  Pele_Mista    Pele_Seca  Pele_Normal  \
# count  1472.000000  1472.000000  1472.00000  1472.000000  1472.000000
# mean     55.584239     4.153261     0.65625     0.614130     0.652174
# std      45.014429     0.633918     0.47512     0.486965     0.476442
# min       3.000000     0.000000     0.00000     0.000000     0.000000
# 25%      30.000000     4.000000     0.00000     0.000000     0.000000
# 50%      42.500000     4.300000     1.00000     1.000000     1.000000
# 75%      68.000000     4.500000     1.00000     1.000000     1.000000
# max     370.000000     5.000000     1.00000     1.000000     1.000000
#
#        Pele_Oleosa  Pele_Sensivel
# count  1472.000000    1472.000000
# mean      0.607337       0.513587
# std       0.488509       0.499985
# min       0.000000       0.000000
# 25%       0.000000       0.000000
# 50%       1.000000       1.000000
# 75%       1.000000       1.000000
# max       1.000000       1.000000

# %%
# Distribuição das variável Tipo
percentage_type = df_cosmetics.value_counts('Tipo') / len(df_cosmetics) * 100
percentage_type = percentage_type.reset_index()
percentage_type.columns = ['Tipo', 'Percentual']

fig = px.bar(percentage_type, x='Tipo', y='Percentual', color='Tipo', text='Percentual')

# Atualizar o Plot para melhor visualizar os labels
fig.update_traces(texttemplate='%{text:.4s}%', textposition='outside')

fig.show()

# %%
# Distribuição das variável Marca
percentage_brand = df_cosmetics.value_counts('Marca') / len(df_cosmetics) * 100
percentage_brand = percentage_brand.reset_index()
percentage_brand.columns = ['Marca', 'Percentual']

fig = px.bar(percentage_brand.head(10), x='Percentual', y='Marca', color='Marca', text='Percentual', orientation='h')

# Atualizar o Plot para melhor visualizar os labels
fig.update_traces(texttemplate='%{text:.4s}%', textposition='outside')

fig.show()

# %%
# Quantidade de Marcas
len(df_cosmetics['Marca'].unique())
# Out:
# 116

# %%
# Distribuição das variável Ingrediente
percentage_ingredient = df_ingredients.value_counts('Ingredientes') / len(df_ingredients) * 100
percentage_ingredient = percentage_ingredient.reset_index()
percentage_ingredient.columns = ['Ingrediente', 'Percentual']

fig = px.bar(percentage_ingredient.head(10), x='Percentual', y='Ingrediente', color='Ingrediente', text='Percentual', orientation='h')

# Atualizar o Plot para melhor visualizar os labels
fig.update_traces(texttemplate='%{text:.4s}%', textposition='outside')

fig.show()

# %%
len(percentage_ingredient['Ingrediente'].unique())
# Out:
# 7298

# %%
# Distribuição da variável Preço
px.histogram(df_cosmetics['Preco'], title='Histograma da variável Preço')

# %%
# Distribuição da variável Rating
px.histogram(df_cosmetics['Rating'], title='Histograma da variável Rating')

# %% [markdown]
# Análise Bivariada

# %%
# Plot de Distribuição (BoxPlot) por Tipo e Preço
px.box(df_cosmetics, x='Preco', y='Tipo', color='Tipo', orientation='h', hover_data=['Marca','Nome'])

# %%
# Plot de Distribuição (BoxPlot) por Tipo e Rating
px.box(df_cosmetics, x='Rating', y='Tipo', color='Tipo', orientation='h', hover_data=['Marca','Nome'])

# %%
# Correlação Preço e Rating
px.scatter(df_cosmetics, x='Preco', y='Rating', color='Tipo', hover_data=['Marca'])

# %%
# Gerar Matriz de Correlação
matriz_correlation_cosmetics = df_cosmetics.corr(numeric_only=True)

# %%
# Plotar matriz de correlação
sns.heatmap(matriz_correlation_cosmetics, vmin=-1, vmax=1, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Treinar o algoritmo t-NSE

# %%
# Copiar Dataframe original
X = df_cosmetics.copy()
X.drop(columns=['Nome', 'Ingredientes'], axis=1, inplace=True)

# %%
# Separando variáves numéricas e categóricas
numeric_features = ['Rating', 'Preco']
categorical_features = ['Marca', 'Tipo']

# %%
# Definir as transformações
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder()

# %%
preprocessor = ColumnTransformer(
  transformers=[
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)
  ],
  remainder='passthrough'
)

# %%
# Transformar os dados
X_transformed = preprocessor.fit_transform(X)

# %%
# Visualizar Dados
X_transformed
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 10368 stored elements and shape (1472, 129)>

# %%
# Armazenar resultados do t-SNE em Dataframe
results_df = pd.DataFrame()

# %%
# Loop de treinamento do algortimo, mudando parâmetro Perplexity
for perplexity in range(5,51,1):

  # Criar e treinar modelo
  tsne = TSNE(n_components=2, perplexity=perplexity, init='random', max_iter=250, random_state=51)
  tsne_results = tsne.fit_transform(X_transformed)

  # Armazenar resultados
  temp_df = pd.DataFrame(tsne_results, columns=['Componente 1', 'Componente 2'])
  temp_df['Perplexity'] = perplexity
  results_df = pd.concat([results_df, temp_df], axis=0)

# %%
results_df.head(10)
# Out:
#    Componente 1  Componente 2  Perplexity
# 0     -0.665999     -0.423478           5
# 1     -0.765371     -0.408072           5
# 2      0.896425      0.060324           5
# 3     -0.679503     -0.412037           5
# 4      1.195807     -0.315665           5
# 5      0.285702     -0.328772           5
# 6      0.891339      0.046689           5
# 7      0.893064      0.059109           5
# 8      1.243963     -0.162615           5
# 9     -1.301838      0.344731           5

# %%
# Reset no Índice para realizar o plot
results_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Visualizar Resultados

# %%
# Criar um ScatterPlot Animado com variação no Perplexity
fig = px.scatter(results_df, x='Componente 1', y='Componente 2', animation_frame='Perplexity', title='Visualização do t-SNE com variação do Perplexity')
fig.show()

# %%
# Armazenar resultados do t-SNE em Dataframe
results_df = pd.DataFrame()

# %%
# Loop de treinamento do algortimo, mudando parâmetro Perplexity
for perplexity in range(5,51,1):

  # Criar e treinar modelo
  tsne = TSNE(n_components=3, perplexity=perplexity, init='random', max_iter=250, random_state=51)
  tsne_results = tsne.fit_transform(X_transformed)

  # Armazenar resultados
  temp_df = pd.DataFrame(tsne_results, columns=['Componente 1', 'Componente 2','Componente 3'])
  temp_df['Perplexity'] = perplexity
  results_df = pd.concat([results_df, temp_df], axis=0)

# %%
# Reset no Índice para realizar o plot
results_df.reset_index(drop=True, inplace=True)

# %%
# Criar um ScatterPlot Animado com variação no Perplexity
fig = px.scatter_3d(results_df, x='Componente 1', y='Componente 2', z='Componente 3', animation_frame='Perplexity', title='Visualização do t-SNE com variação do Perplexity')
fig.show()
